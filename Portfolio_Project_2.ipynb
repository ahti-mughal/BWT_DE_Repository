# %% [markdown]
# <a href="https://colab.research.google.com/github/nadeemtaj407/BWT_DE_Repository/blob/main/Portfolio_Project_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python Libraries

# %%
import pandas as pd # Pandas is used for working with datasets
import numpy as np #Numpy is a library for working with arrays of data
import matplotlib.pyplot as plt #Matplotlib is a library for making graphs
import seaborn as sns #Seaborn is a higher-level interface to Matplotlib that can be used to simplify many graphing tasks
import scipy as sp # Scipy is a library of techniques for numerical and scientific computing
import statsmodels as sts # Statsmodels is a library that implements many statistical techniques

# %% [markdown]
# Importing Data

# %%
df=pd.read_csv("/content/drive/MyDrive/Portfolio project 2 /IPL/IPL_Ball_by_Ball_2022.csv")
df_ipl=pd.read_csv("/content/drive/MyDrive/Portfolio project 2 /IPL/IPL_Matches_2022.csv")

# %%
df_ipl.head()
# Out:
#         ID       City        Date  Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29    2022        Final
# 1  1312199  Ahmedabad  2022-05-27    2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25    2022   Eliminator
# 3  1312197    Kolkata  2022-05-24    2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22    2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
df.head()
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# ...

# %%
df
# Out:
#             ID  innings  overs  ballnumber       batter          bowler  \
# 0      1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1      1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2      1312200        1      0           3   JC Buttler  Mohammed Shami
# 3      1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4      1312200        1      0           5  YBK Jaiswal  Mohammed Shami
# ...        ...      ...    ...         ...          ...             ...
# 17907  1304047        2     17           5      SS Iyer        DJ Bravo
# 17908  1304047        2     17           6   SP Jackson        DJ Bravo
# 17909  1304047        2     18           1   SP Jackson        AF Milne
# 17910  1304047        2     18           2      SS Iyer        AF Milne
# 17911  1304047        2     18           3      SS Iyer        AF Milne
#
#        non-striker extra_type  batsman_run  extras_run  total_run  \
# ...

# %%
df.shape
# Out:
# (17912, 17)

# %%
df.columns
# Out:
# Index(['ID', 'innings', 'overs', 'ballnumber', 'batter', 'bowler',
#        'non-striker', 'extra_type', 'batsman_run', 'extras_run', 'total_run',
#        'non_boundary', 'isWicketDelivery', 'player_out', 'kind',
#        'fielders_involved', 'BattingTeam'],
#       dtype='object')

# %% [markdown]
# Lets say we would like to splice our data frame and select only specific portions of our data.
#
# There are three different ways of doing so.
#
# .loc()
# .iloc()
# .ix()
# We will cover the .loc() and .iloc() splicing functions.
#
# .loc()
# .loc() takes two single/list/range operator separated by ','. The first one indicates the row and the second one indicates columns.

# %% [markdown]
# ##.loc()

# %%
# Return all observations of batter
df.loc[:, "batter"]
# Out:
# 0        YBK Jaiswal
# 1        YBK Jaiswal
# 2         JC Buttler
# 3        YBK Jaiswal
# 4        YBK Jaiswal
#             ...
# 17907        SS Iyer
# 17908     SP Jackson
# 17909     SP Jackson
# 17910        SS Iyer
# 17911        SS Iyer
# Name: batter, Length: 17912, dtype: object

# %%
#select all rows of multiples columns ["innings", "overs", "ballnumber"] 
df.loc[:, ["innings", "overs", "ballnumber"]]
# Out:
#        innings  overs  ballnumber
# 0            1      0           1
# 1            1      0           2
# 2            1      0           3
# 3            1      0           4
# 4            1      0           5
# ...        ...    ...         ...
# 17907        2     17           5
# 17908        2     17           6
# 17909        2     18           1
# 17910        2     18           2
# 17911        2     18           3
#
# [17912 rows x 3 columns]

# %%
#select 10 rows of multiples columns ["innings", "overs", "ballnumber"] 
df.loc[:9, ["innings", "overs", "ballnumber"]]
# Out:
#    innings  overs  ballnumber
# 0        1      0           1
# 1        1      0           2
# 2        1      0           3
# 3        1      0           4
# 4        1      0           5
# 5        1      0           6
# 6        1      1           1
# 7        1      1           2
# 8        1      1           3
# 9        1      1           4

# %%
# Select range of rows for all columns
df.loc[5:10]
# Out:
#          ID  innings  overs  ballnumber       batter          bowler  \
# 5   1312200        1      0           6  YBK Jaiswal  Mohammed Shami
# 6   1312200        1      1           1   JC Buttler      Yash Dayal
# 7   1312200        1      1           2   JC Buttler      Yash Dayal
# 8   1312200        1      1           3   JC Buttler      Yash Dayal
# 9   1312200        1      1           4   JC Buttler      Yash Dayal
# 10  1312200        1      1           5   JC Buttler      Yash Dayal
#
#     non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 5    JC Buttler        NaN            0           0          0             0
# 6   YBK Jaiswal        NaN            0           0          0             0
# 7   YBK Jaiswal        NaN            0           0          0             0
# 8   YBK Jaiswal        NaN            4           0          4             0
# 9   YBK Jaiswal        NaN            0           0          0             0
# ...

# %%
# Firts 5 rows of any specific columns
df.loc[:5, "innings"]
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# 5    1
# Name: innings, dtype: int64

# %% [markdown]
# ##.iloc()
#
# .iloc() is integer based slicing, whereas .loc() used labels/column names.

# %%
df.iloc[:4]
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# 0                 0        NaN  NaN               NaN  Rajasthan Royals
# 1                 0        NaN  NaN               NaN  Rajasthan Royals
# ...

# %%
#specific rows and columns
df.iloc[1:10, :3 ]
# Out:
#         ID  innings  overs
# 1  1312200        1      0
# 2  1312200        1      0
# 3  1312200        1      0
# 4  1312200        1      0
# 5  1312200        1      0
# 6  1312200        1      1
# 7  1312200        1      1
# 8  1312200        1      1
# 9  1312200        1      1

# %%
#Show datatypes of each columns
df.dtypes
# Out:
# ID                    int64
# innings               int64
# overs                 int64
# ballnumber            int64
# batter               object
# bowler               object
# non-striker          object
# extra_type           object
# batsman_run           int64
# extras_run            int64
# total_run             int64
# non_boundary          int64
# isWicketDelivery      int64
# player_out           object
# kind                 object
# fielders_involved    object
# BattingTeam          object
# dtype: object

# %%
df["BattingTeam"].unique()
# Out:
# array(['Rajasthan Royals', 'Gujarat Titans',
#        'Royal Challengers Bangalore', 'Lucknow Super Giants',
#        'Sunrisers Hyderabad', 'Punjab Kings', 'Delhi Capitals',
#        'Mumbai Indians', 'Chennai Super Kings', 'Kolkata Knight Riders'],
#       dtype=object)

# %%
#list unique values of columns ["Batter"]
df.batter.unique()
# Out:
# array(['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D Padikkal',
#        'SO Hetmyer', 'R Ashwin', 'R Parag', 'TA Boult', 'OC McCoy',
#        'WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pandya', 'DA Miller',
#        'V Kohli', 'F du Plessis', 'RM Patidar', 'GJ Maxwell', 'MK Lomror',
#        'KD Karthik', 'Shahbaz Ahmed', 'PWH de Silva', 'HV Patel',
#        'JR Hazlewood', 'Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda',
#        'MP Stoinis', 'E Lewis', 'KH Pandya', 'PVD Chameera', 'PK Garg',
#        'Abhishek Sharma', 'RA Tripathi', 'AK Markram', 'N Pooran',
#        'Washington Sundar', 'R Shepherd', 'J Suchith', 'B Kumar',
#        'Umran Malik', 'JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',
#        'MA Agarwal', 'LS Livingstone', 'JM Sharma', 'PN Mankad',
#        'PP Shaw', 'DA Warner', 'MR Marsh', 'RR Pant', 'SN Khan',
#        'R Powell', 'AR Patel', 'SN Thakur', 'Kuldeep Yadav',
#        'Ishan Kishan', 'RG Sharma', 'D Brevis', 'Tilak Varma', 'TH David',
# ...

# %%
df.extras_run.unique()
# Out:
# array([0, 1, 5, 4, 2, 3])

# %%
# Use .loc() to specify a list of mulitple column names
df.loc[:, ["innings", "overs", "extras_run"]]
# Out:
#        innings  overs  extras_run
# 0            1      0           0
# 1            1      0           1
# 2            1      0           0
# 3            1      0           0
# 4            1      0           0
# ...        ...    ...         ...
# 17907        2     17           0
# 17908        2     17           0
# 17909        2     18           0
# 17910        2     18           0
# 17911        2     18           0
#
# [17912 rows x 3 columns]

# %%
df.groupby(["batter"]).size() #confusion?
# Out:
# batter
# A Badoni             139
# A Manohar             79
# A Nortje               7
# A Tomar                8
# AD Russell           200
#                     ...
# WP Saha              266
# Washington Sundar     76
# YBK Jaiswal          198
# YS Chahal              8
# Yash Dayal             1
# Length: 174, dtype: int64

# %%
#Most number of ball faced a any batter
df["batter"].max()
# Out:
# 'Yash Dayal'

# %%
#Least number of ball faced by a batter
df["batter"].min()
# Out:
# 'A Badoni'

# %% [markdown]
# ##Missing Values

# %%
#in extra_type
pd.isnull(df.extra_type).sum()
# Out:
# 16862

# %%
#in extras_run
pd.isnull(df.extras_run).sum()
# Out:
# 0

# %%
#whole datasets
pd.isnull(df).sum()
# Out:
# ID                       0
# innings                  0
# overs                    0
# ballnumber               0
# batter                   0
# bowler                   0
# non-striker              0
# extra_type           16862
# batsman_run              0
# extras_run               0
# total_run                0
# non_boundary             0
# isWicketDelivery         0
# player_out           17000
# kind                 17000
# fielders_involved    17208
# BattingTeam              0
# dtype: int64

# %%
df.head()
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# ...

# %%
#the summary statistics for the quantitative variables
df.describe()
# Out:
#                  ID       innings         overs    ballnumber   batsman_run  \
# count  1.791200e+04  17912.000000  17912.000000  17912.000000  17912.000000
# mean   1.304524e+06      1.485317      9.290085      3.652077      1.286958
# std    1.843446e+03      0.499798      5.690914      1.837818      1.701842
# min    1.304047e+06      1.000000      0.000000      1.000000      0.000000
# 25%    1.304065e+06      1.000000      4.000000      2.000000      0.000000
# 50%    1.304084e+06      1.000000      9.000000      4.000000      1.000000
# 75%    1.304102e+06      2.000000     14.000000      5.000000      1.000000
# max    1.312200e+06      2.000000     19.000000     10.000000      6.000000
#
#          extras_run     total_run  non_boundary  isWicketDelivery
# count  17912.000000  17912.000000  17912.000000      17912.000000
# mean       0.074978      1.361936      0.000167          0.050916
# std        0.372878      1.688991      0.012941          0.219831
# ...

# %%
df.batter.describe()
# Out:
# count          17912
# unique           174
# top       JC Buttler
# freq             596
# Name: batter, dtype: object

# %%
df.overs.describe()
# Out:
# count    17912.000000
# mean         9.290085
# std          5.690914
# min          0.000000
# 25%          4.000000
# 50%          9.000000
# 75%         14.000000
# max         19.000000
# Name: overs, dtype: float64

# %%
#Total Numbers of run made throughout IPL 2022
df.batsman_run.sum()
# Out:
# 23052

# %%
#Total numbers of wickets 
df.isWicketDelivery.sum()
# Out:
# 912

# %%
#top 5 scorer in ipl 2022
Score=df.groupby(['batter'])[['batsman_run']].sum()
Score.reset_index(inplace=True)
plt.figure(figsize=(20,6))
plt.title('Top 3 scorer in IPL 2022',size=15,fontweight='bold')
plt.xticks(rotation = 90)
plt.grid(visible=True)
ax=sns.barplot(data=Score.sort_values('batsman_run',ascending=False).head(5),
            x='batter',y='batsman_run',palette='viridis')
for i in ax.containers:
    ax.bar_label(i,)

# %%
#Show each player runs w.r.t each inningas
runs = df.groupby(['batter','ID'])[['batsman_run']].sum()
runs
# Out:
#                      batsman_run
# batter      ID
# A Badoni    1304050           54
#             1304053           19
#             1304058           19
#             1304061           10
#             1304066            5
# ...                          ...
# YBK Jaiswal 1312197            3
#             1312199           21
#             1312200           22
# YS Chahal   1304070            5
# Yash Dayal  1304081            0
#
# [1158 rows x 1 columns]

# %%
runs.reset_index(inplace=True)
runs
# Out:
#            batter       ID  batsman_run
# 0        A Badoni  1304050           54
# 1        A Badoni  1304053           19
# 2        A Badoni  1304058           19
# 3        A Badoni  1304061           10
# 4        A Badoni  1304066            5
# ...           ...      ...          ...
# 1153  YBK Jaiswal  1312197            3
# 1154  YBK Jaiswal  1312199           21
# 1155  YBK Jaiswal  1312200           22
# 1156    YS Chahal  1304070            5
# 1157   Yash Dayal  1304081            0
#
# [1158 rows x 3 columns]

# %%
##sns.boxplot()?
#sns.boxplot, y="isWicketDelivery", data=df)

# %% [markdown]
# ##frequncy distributions

# %%
#Numbers of balls in 1st and 2nd innings
df.innings.replace({1: "First Innings", 2:"2nd Innings"})
# Out:
# 0        First Innings
# 1        First Innings
# 2        First Innings
# 3        First Innings
# 4        First Innings
#              ...
# 17907      2nd Innings
# 17908      2nd Innings
# 17909      2nd Innings
# 17910      2nd Innings
# 17911      2nd Innings
# Name: innings, Length: 17912, dtype: object

# %%
#Number of develiveries in 1st and 2nd innings
df.innings.value_counts()
# Out:
# 1    9219
# 2    8693
# Name: innings, dtype: int64

# %%
df.innings.value_counts().sum()
# Out:
# 17912

# %%
df_ipl.head()
# Out:
#         ID       City        Date  Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29    2022        Final
# 1  1312199  Ahmedabad  2022-05-27    2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25    2022   Eliminator
# 3  1312197    Kolkata  2022-05-24    2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22    2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %% [markdown]
# #Graphicals summaries

# %%
#graphicals summaries
sns.distplot(df["innings"])
# Out:
# <ipython-input-40-3c60c8e29955>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["innings"])
# <Axes: xlabel='innings', ylabel='Density'>

# %%
sns.boxplot(data=df.loc[:,["overs", "batsman_run"]])
# Out:
# <Axes: >

# %% [markdown]
# #Stratifications

# %%
df.head()
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# ...

# %%
df["overs_interval"]=pd.cut(df.overs, [0,5,10,15,20])

# %%
sns.boxplot(x="overs_interval", y="ballnumber", data=df)
# Out:
# <Axes: xlabel='overs_interval', ylabel='ballnumber'>

# %% [markdown]
# #Week 3
# replicating the Concepts

# %% [markdown]
# ##Multi-variate Data

# %%
col_names=df.columns
col_names
# Out:
# Index(['ID', 'innings', 'overs', 'ballnumber', 'batter', 'bowler',
#        'non-striker', 'extra_type', 'batsman_run', 'extras_run', 'total_run',
#        'non_boundary', 'isWicketDelivery', 'player_out', 'kind',
#        'fielders_involved', 'BattingTeam', 'overs_interval'],
#       dtype='object')

# %%
#Another way to get only column names that include 'Bat' is with list comprehension
#[keep x for x in list if condition met]
[column for column in col_names if 'at' in column]
# Out:
# ['batter', 'batsman_run', 'BattingTeam']

# %%
#save the columns
keep=[column for column in col_names if 'at' in column]

# %%
df_bat=df[keep]

# %%
df_bat.head()
# Out:
#         batter  batsman_run       BattingTeam
# 0  YBK Jaiswal            0  Rajasthan Royals
# 1  YBK Jaiswal            0  Rajasthan Royals
# 2   JC Buttler            1  Rajasthan Royals
# 3  YBK Jaiswal            0  Rajasthan Royals
# 4  YBK Jaiswal            0  Rajasthan Royals

# %%
df.loc[:, keep].head()
# Out:
#         batter  batsman_run       BattingTeam
# 0  YBK Jaiswal            0  Rajasthan Royals
# 1  YBK Jaiswal            0  Rajasthan Royals
# 2   JC Buttler            1  Rajasthan Royals
# 3  YBK Jaiswal            0  Rajasthan Royals
# 4  YBK Jaiswal            0  Rajasthan Royals

# %%
index_bool=np.isin(df.columns, keep)
index_bool
# Out:
# array([False, False, False, False,  True, False, False, False,  True,
#        False, False, False, False, False, False, False,  True, False])

# %%
df.iloc[:, index_bool].head()
# Out:
#         batter  batsman_run       BattingTeam
# 0  YBK Jaiswal            0  Rajasthan Royals
# 1  YBK Jaiswal            0  Rajasthan Royals
# 2   JC Buttler            1  Rajasthan Royals
# 3  YBK Jaiswal            0  Rajasthan Royals
# 4  YBK Jaiswal            0  Rajasthan Royals

# %% [markdown]
# ##Selection by condtions

# %%
# Lets only look at rows who 'Ballnumber' is larger than the median
waist_median = pd.Series.median(df['ballnumber']) # get the median of
waist_median
# Out:
# 4.0

# %%
df[df["ballnumber"]> waist_median].head()
# Out:
#          ID  innings  overs  ballnumber       batter          bowler  \
# 4   1312200        1      0           5  YBK Jaiswal  Mohammed Shami
# 5   1312200        1      0           6  YBK Jaiswal  Mohammed Shami
# 10  1312200        1      1           5   JC Buttler      Yash Dayal
# 11  1312200        1      1           6  YBK Jaiswal      Yash Dayal
# 16  1312200        1      2           5  YBK Jaiswal  Mohammed Shami
#
#     non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 4    JC Buttler        NaN            0           0          0             0
# 5    JC Buttler        NaN            0           0          0             0
# 10  YBK Jaiswal        NaN            1           0          1             0
# 11   JC Buttler        NaN            0           0          0             0
# 16   JC Buttler        NaN            6           0          6             0
#
#     isWicketDelivery player_out kind fielders_involved       BattingTeam  \
# ...

# %%
# Lets add another condition, that 'Batsman' must be greater 1
condition1 = df['batsman_run'] < waist_median
condition2 = df['batsman_run'] > 1
df[condition1 & condition2].head() 
# Using [] method
# Note: can't use 'and' instead of '&'
# Out:
#           ID  innings  overs  ballnumber       batter          bowler  \
# 17   1312200        1      2           6  YBK Jaiswal  Mohammed Shami
# 21   1312200        1      3           4  YBK Jaiswal      Yash Dayal
# 55   1312200        1      9           2   JC Buttler  Mohammed Shami
# 60   1312200        1     10           1   JC Buttler       HH Pandya
# 102  1312200        1     17           1     TA Boult   R Sai Kishore
#
#     non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 17   JC Buttler        NaN            3           0          3             0
# 21   JC Buttler        NaN            2           0          2             0
# 55   D Padikkal        NaN            2           0          2             0
# 60   D Padikkal        NaN            2           0          2             0
# 102     R Parag        NaN            2           0          2             0
#
#      isWicketDelivery player_out kind fielders_involved       BattingTeam  \
# ...

# %%
#using loc method
df.loc[condition1 & condition2,:].head()
# Out:
#           ID  innings  overs  ballnumber       batter          bowler  \
# 17   1312200        1      2           6  YBK Jaiswal  Mohammed Shami
# 21   1312200        1      3           4  YBK Jaiswal      Yash Dayal
# 55   1312200        1      9           2   JC Buttler  Mohammed Shami
# 60   1312200        1     10           1   JC Buttler       HH Pandya
# 102  1312200        1     17           1     TA Boult   R Sai Kishore
#
#     non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 17   JC Buttler        NaN            3           0          3             0
# 21   JC Buttler        NaN            2           0          2             0
# 55   D Padikkal        NaN            2           0          2             0
# 60   D Padikkal        NaN            2           0          2             0
# 102     R Parag        NaN            2           0          2             0
#
#      isWicketDelivery player_out kind fielders_involved       BattingTeam  \
# ...
